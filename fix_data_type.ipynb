# %%
import pandas as pd

# %%
df = pd.read_excel("fake3000.xlsx")

# %%
df.columns
# Out:
# Index(['Id', 'Sarlavha', 'Matn', 'Sana', 'Manba'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Id        3000 non-null   int64
#  1   Sarlavha  3000 non-null   object
#  2   Matn      3000 non-null   object
#  3   Sana      3000 non-null   object
#  4   Manba     3000 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 117.3+ KB

# %%
df.head(10)
# Out:
#    Id                                           Sarlavha  \
# 0   1  Epshteyn hujjatlari: millionlab fayllar, mish-...
# 1   2  Xitoyda bola tug‘ib beradigan robot kashf qili...
# 2   3  Feyk: Shvetsiyada har to‘rtinchi ayol zo‘ravon...
# 3   4    Brijit Makron haqida feyk tarqatganlar sudlandi
# 4   5  Netanyahuning “o‘limi” va “sun’iy intellekt vi...
# 5   6  Eron urushi haqida tarqalayotgan videolar: qay...
# 6   7  Zelenskiy AstraZeneca kompaniyasining 1% aksiy...
# 7   8  Instagramdagi da’vo: “kaltakesaklar virus tarq...
# 8   9  Faktchecking: Buyuk Britaniya parlamenti a’zos...
# 9  10  Haqiqat va sun’iylik o‘rtasida: Venesuela voqe...
#
#                                                 Matn                 Sana  \
# 0  AQSh Adliya vazirligi amerikalik moliyachi, qa...  2026-02-05 00:00:00
# 1  2025-yil avgustida butun dunyoda “Xitoy kompan...  2025-09-01 00:00:00
# 2  Ijtimoiy tarmoqlarning prorossiyacha segmentid...  2025-12-29 00:00:00
# ...

# %%
# 1. Avval ustunni sana formatiga o'tkazamiz (agar hali o'tkazilmagan bo'lsa)
df['Sana'] = pd.to_datetime(df['Sana'])

# 2. Uni dd.mm.yyyy formatidagi matnga aylantiramiz
df['Sana'] = df['Sana'].dt.strftime('%d.%m.%Y')

# Natijani ko'rish
print(df['Sana'].head())
# Out:
# 0    05.02.2026
# 1    01.09.2025
# 2    29.12.2025
# 3    06.01.2026
# 4    05.02.2026
# Name: Sana, dtype: object

# %%
print(df['Sana'].head(5))
# Out:
# 0    05.02.2026
# 1    01.09.2025
# 2    29.12.2025
# 3    06.01.2026
# 4    05.02.2026
# Name: Sana, dtype: object

# %%
file_name = "fake_dataset_3000.xlsx"
df.to_excel(file_name, index=False)

print(f"saqlandi {file_name}")
# Out:
# saqlandi fake_dataset_3000.xlsx
